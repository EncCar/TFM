# %% [markdown]
# ## PROBLEMA
# Por el aumento del tráfico de transporte de Mercancías por vía marítima. Se realiza la Predicción para los siguientes meses del flujo de Mercancías total para las principales Autoridades Porturarias españolas.

# %% [markdown]
# ## LIBRERÍAS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## DATOS

# %%
trafico = pd.read_csv('trafic.csv')
display(trafico.head())
display(trafico.shape)
# Out:
#    Unnamed: 0  Autoridad_Portuaria  Graneles Líquidos t  Graneles Sólidos t  \
# 0           0                    1               623294              464559
# 1           1                    2                    0              119575
# 2           2                    3                 7512              266992
# 3           3                    4                74703              189219
# 4           4                    5              2268541              207212
#
#    Mercancía General t  Mercancia General Contenedores t  \
# 0                79616                                 0
# 1               104040                             97163
# 2               134447                             35899
# 3                97892                                 0
# 4              6062831                           4742267
#
#    Mercancías En Tránsito t  Tráfico Ro-Ro t  TEUS Contenedores  \
# 0                     92330                0                0.0
# 1                      4663               59            14934.0
# 2                       141            71601             2129.5
# 3                      3025                0                0.0
# 4                   5304368          1304479           396644.0
#
#    Total_pasajeros  Anios  Mes       fecha  Total_buques  Total_automoviles  \
# 0             4722   2022    1  2022-01-01            94                  0
# 1            11874   2022    1  2022-01-01            44               2257
# 2            13819   2022    1  2022-01-01          3115               3566
# 3                0   2022    1  2022-01-01            65                  0
# 4           112032   2022    1  2022-01-01         42993              17298
#
#    Total_toneladas
# 0          1259799
# 1           325500
# 2           516592
# 3           364839
# 4         19889698
# (784, 16)

# %%
# Eliminación de variables innecesarias 
trafico = trafico.drop('Unnamed: 0', axis=1)

# %%
trafico.dtypes
# Out:
# Autoridad_Portuaria                   int64
# Graneles Líquidos t                   int64
# Graneles Sólidos t                    int64
# Mercancía General t                   int64
# Mercancia General Contenedores t      int64
# Mercancías En Tránsito t              int64
# Tráfico Ro-Ro t                       int64
# TEUS Contenedores                   float64
# Total_pasajeros                       int64
# Anios                                 int64
# Mes                                   int64
# fecha                                object
# Total_buques                          int64
# Total_automoviles                     int64
# Total_toneladas                       int64
# dtype: object

# %%
trafico['fecha'] = pd.to_datetime(trafico['fecha'])
trafico.head()
# Out:
#    Autoridad_Portuaria  Graneles Líquidos t  Graneles Sólidos t  \
# 0                    1               623294              464559
# 1                    2                    0              119575
# 2                    3                 7512              266992
# 3                    4                74703              189219
# 4                    5              2268541              207212
#
#    Mercancía General t  Mercancia General Contenedores t  \
# 0                79616                                 0
# 1               104040                             97163
# 2               134447                             35899
# 3                97892                                 0
# 4              6062831                           4742267
#
#    Mercancías En Tránsito t  Tráfico Ro-Ro t  TEUS Contenedores  \
# 0                     92330                0                0.0
# 1                      4663               59            14934.0
# 2                       141            71601             2129.5
# 3                      3025                0                0.0
# 4                   5304368          1304479           396644.0
#
#    Total_pasajeros  Anios  Mes      fecha  Total_buques  Total_automoviles  \
# 0             4722   2022    1 2022-01-01            94                  0
# 1            11874   2022    1 2022-01-01            44               2257
# 2            13819   2022    1 2022-01-01          3115               3566
# 3                0   2022    1 2022-01-01            65                  0
# 4           112032   2022    1 2022-01-01         42993              17298
#
#    Total_toneladas
# 0          1259799
# 1           325500
# 2           516592
# 3           364839
# 4         19889698

# %%
trafico.dtypes
# Out:
# Autoridad_Portuaria                          int64
# Graneles Líquidos t                          int64
# Graneles Sólidos t                           int64
# Mercancía General t                          int64
# Mercancia General Contenedores t             int64
# Mercancías En Tránsito t                     int64
# Tráfico Ro-Ro t                              int64
# TEUS Contenedores                          float64
# Total_pasajeros                              int64
# Anios                                        int64
# Mes                                          int64
# fecha                               datetime64[ns]
# Total_buques                                 int64
# Total_automoviles                            int64
# Total_toneladas                              int64
# dtype: object

# %% [markdown]
# ## BARCELONA

# %%
df_barcelona = trafico[trafico['Autoridad_Portuaria'] == 8]
df_barcelona.head()
# Out:
#      Autoridad_Portuaria  Graneles Líquidos t  Graneles Sólidos t  \
# 7                      8              1507323              252729
# 35                     8              1375011              413006
# 63                     8              1488794              527472
# 91                     8              1172927              312945
# 119                    8              1281589              505174
#
#      Mercancía General t  Mercancia General Contenedores t  \
# 7                3811267                           3015822
# 35               3658040                           2740901
# 63               4474862                           3461354
# 91               4300236                           3380549
# 119              4678231                           3625521
#
#      Mercancías En Tránsito t  Tráfico Ro-Ro t  TEUS Contenedores  \
# 7                     2122201           809627          293935.75
# 35                    1901341           913036          264193.50
# 63                    2828676          1034998          319486.00
# 91                    2243082           904860          301119.50
# 119                   2417518          1086764          333401.50
#
#      Total_pasajeros  Anios  Mes      fecha  Total_buques  Total_automoviles  \
# 7              78059   2022    1 2022-01-01         30533              35207
# 35             71312   2022    2 2022-02-01         33796              52804
# 63            102565   2022    3 2022-03-01         38778              56590
# 91            234929   2022    4 2022-04-01         34396              72323
# 119           303184   2022    5 2022-05-01         39847              78794
#
#      Total_toneladas
# 7           11518969
# 35          11001335
# 63          13816156
# 91          12314599
# 119         13594797

# %%
df_barcelona = df_barcelona.drop('Autoridad_Portuaria', axis=1)

# %%
datos_barcelona = df_barcelona[['Total_toneladas']]

# %%
datos_barcelona
# Out:
#      Total_toneladas
# 7           11518969
# 35          11001335
# 63          13816156
# 91          12314599
# 119         13594797
# 147         11853838
# 175         13088963
# 203         12604395
# 231         10946080
# 259         11009727
# 287         10467607
# 315         11642714
# 343         10337972
# 371          9607904
# 399         10917639
# 427         10712995
# 455         12045143
# 483         10630872
# 511         11092923
# 539         10005943
# 567         10108634
# 595         10938198
# 623         11302964
# 651         10386884
# 679         10776039
# 707         11688430
# 735         13279089
# 763         12544966

# %%
datos_barcelona.to_excel('autoridades/barcelona.xlsx')

# %%
df_barcelona.dtypes
# Out:
# Graneles Líquidos t                          int64
# Graneles Sólidos t                           int64
# Mercancía General t                          int64
# Mercancia General Contenedores t             int64
# Mercancías En Tránsito t                     int64
# Tráfico Ro-Ro t                              int64
# TEUS Contenedores                          float64
# Total_pasajeros                              int64
# Anios                                        int64
# Mes                                          int64
# fecha                               datetime64[ns]
# Total_buques                                 int64
# Total_automoviles                            int64
# Total_toneladas                              int64
# dtype: object

# %%
df_barcelona.describe()
# Out:
#        Graneles Líquidos t  Graneles Sólidos t  Mercancía General t  \
# count         2.800000e+01           28.000000         2.800000e+01
# mean          1.159159e+06       383277.357143         3.952403e+06
# min           7.660730e+05       249318.000000         3.354054e+06
# 25%           1.004664e+06       316491.500000         3.647672e+06
# 50%           1.136085e+06       365792.500000         3.839200e+06
# 75%           1.303195e+06       428137.750000         4.234930e+06
# max           1.738260e+06       580465.000000         4.678231e+06
# std           2.301109e+05        86591.124332         3.744924e+05
#
#        Mercancia General Contenedores t  Mercancías En Tránsito t  \
# count                      2.800000e+01              2.800000e+01
# mean                       3.010019e+06              1.967278e+06
# min                        2.441873e+06              1.434017e+06
# 25%                        2.765425e+06              1.738678e+06
# 50%                        2.932830e+06              1.911687e+06
# 75%                        3.206611e+06              2.193962e+06
# max                        3.625521e+06              2.828676e+06
# std                        3.324579e+05              3.389957e+05
#
#        Tráfico Ro-Ro t  TEUS Contenedores  Total_pasajeros        Anios  \
# count     2.800000e+01          28.000000        28.000000    28.000000
# mean      9.648549e+05      289132.133929    364198.142857  2022.714286
# min       7.820220e+05      229580.500000     71312.000000  2022.000000
# 25%       9.010170e+05      272237.875000    194205.250000  2022.000000
# 50%       9.626060e+05      285012.500000    336820.500000  2023.000000
# 75%       1.062768e+06      303044.875000    551174.750000  2023.000000
# max       1.119585e+06      348007.000000    801169.000000  2024.000000
# std       1.011614e+05       28747.021365    215082.999992     0.712697
#
#              Mes                          fecha  Total_buques  \
# count  28.000000                             28     28.000000
# mean    5.928571  2023-02-14 22:17:08.571428608  35269.214286
# min     1.000000            2022-01-01 00:00:00  27595.000000
# 25%     3.000000            2022-07-24 06:00:00  33793.500000
# 50%     5.500000            2023-02-15 00:00:00  35071.000000
# 75%     9.000000            2023-09-08 12:00:00  38939.250000
# max    12.000000            2024-04-01 00:00:00  41416.000000
# std     3.579040                            NaN   4086.647901
#
#        Total_automoviles  Total_toneladas
# count          28.000000     2.800000e+01
# mean        97452.678571     1.143699e+07
# min         35207.000000     9.607904e+06
# 25%         78962.000000     1.069246e+07
# 50%         95803.000000     1.105132e+07
# 75%        108428.750000     1.211251e+07
# max        164861.000000     1.381616e+07
# std         29773.042468     1.117914e+06

# %%
df_barcelona.tail()
# Out:
#      Graneles Líquidos t  Graneles Sólidos t  Mercancía General t  \
# 651              1025011              361708              3607547
# 679               766073              324206              3843295
# 707              1012582              362565              4046216
# 735              1189649              396163              4563660
# 763              1042996              314063              4453149
#
#      Mercancia General Contenedores t  Mercancías En Tránsito t  \
# 651                           2827043                   1783553
# 679                           3011767                   1989352
# 707                           3148202                   2177589
# 735                           3550731                   2561161
# 763                           3429166                   2290086
#
#      Tráfico Ro-Ro t  TEUS Contenedores  Total_pasajeros  Anios  Mes  \
# 651           782022          279753.50           218805   2023   12
# 679           841346          295527.75           179890   2024    1
# 707           941276          308120.50           132848   2024    2
# 735          1017725          348007.00           254704   2024    3
# 763          1015506          338986.25           395390   2024    4
#
#          fecha  Total_buques  Total_automoviles  Total_toneladas
# 651 2023-12-01         27595              94931         10386884
# 679 2024-01-01         29079              72169         10776039
# 707 2024-02-01         33989              79018         11688430
# 735 2024-03-01         37031             103348         13279089
# 763 2024-04-01         37939              92386         12544966

# %%
df_barcelona =df_barcelona.set_index('fecha')

# %%
df_barcelona.head()
# Out:
#             Graneles Líquidos t  Graneles Sólidos t  Mercancía General t  \
# fecha
# 2022-01-01              1507323              252729              3811267
# 2022-02-01              1375011              413006              3658040
# 2022-03-01              1488794              527472              4474862
# 2022-04-01              1172927              312945              4300236
# 2022-05-01              1281589              505174              4678231
#
#             Mercancia General Contenedores t  Mercancías En Tránsito t  \
# fecha
# 2022-01-01                           3015822                   2122201
# 2022-02-01                           2740901                   1901341
# 2022-03-01                           3461354                   2828676
# 2022-04-01                           3380549                   2243082
# 2022-05-01                           3625521                   2417518
#
#             Tráfico Ro-Ro t  TEUS Contenedores  Total_pasajeros  Anios  Mes  \
# fecha
# 2022-01-01           809627          293935.75            78059   2022    1
# 2022-02-01           913036          264193.50            71312   2022    2
# 2022-03-01          1034998          319486.00           102565   2022    3
# 2022-04-01           904860          301119.50           234929   2022    4
# 2022-05-01          1086764          333401.50           303184   2022    5
#
#             Total_buques  Total_automoviles  Total_toneladas
# fecha
# 2022-01-01         30533              35207         11518969
# 2022-02-01         33796              52804         11001335
# 2022-03-01         38778              56590         13816156
# 2022-04-01         34396              72323         12314599
# 2022-05-01         39847              78794         13594797

# %% [markdown]
# ## Selección de Variables Barcelona
#
# Utilización de la Correlación entre cada una de las características y la variable a predecir.

# %%
corr_matriz_barcelona = df_barcelona.corr(method='pearson')
corr_matriz_barcelona
# Out:
#                                   Graneles Líquidos t  Graneles Sólidos t  \
# Graneles Líquidos t                          1.000000            0.147940
# Graneles Sólidos t                           0.147940            1.000000
# Mercancía General t                          0.076175            0.031801
# Mercancia General Contenedores t             0.079815           -0.040664
# Mercancías En Tránsito t                     0.429576            0.055793
# Tráfico Ro-Ro t                             -0.038176            0.253153
# TEUS Contenedores                           -0.057692           -0.023131
# Total_pasajeros                             -0.380877           -0.200475
# Anios                                       -0.507212           -0.046000
# Mes                                          0.070257            0.002151
# Total_buques                                -0.010539            0.213638
# Total_automoviles                           -0.364546           -0.073166
# Total_toneladas                              0.393363            0.146296
#
#                                   Mercancía General t  \
# Graneles Líquidos t                          0.076175
# Graneles Sólidos t                           0.031801
# Mercancía General t                          1.000000
# Mercancia General Contenedores t             0.971273
# Mercancías En Tránsito t                     0.814475
# Tráfico Ro-Ro t                              0.504181
# TEUS Contenedores                            0.909804
# Total_pasajeros                              0.144735
# Anios                                       -0.068289
# Mes                                         -0.182399
# Total_buques                                 0.581195
# Total_automoviles                            0.038288
# Total_toneladas                              0.934589
#
#                                   Mercancia General Contenedores t  \
# Graneles Líquidos t                                       0.079815
# Graneles Sólidos t                                       -0.040664
# Mercancía General t                                       0.971273
# Mercancia General Contenedores t                          1.000000
# Mercancías En Tránsito t                                  0.864325
# Tráfico Ro-Ro t                                           0.288502
# TEUS Contenedores                                         0.944355
# Total_pasajeros                                           0.064809
# Anios                                                    -0.062615
# Mes                                                      -0.206955
# Total_buques                                              0.386285
# Total_automoviles                                        -0.022301
# Total_toneladas                                           0.924244
#
#                                   Mercancías En Tránsito t  Tráfico Ro-Ro t  \
# Graneles Líquidos t                               0.429576        -0.038176
# Graneles Sólidos t                                0.055793         0.253153
# Mercancía General t                               0.814475         0.504181
# Mercancia General Contenedores t                  0.864325         0.288502
# Mercancías En Tránsito t                          1.000000         0.122009
# Tráfico Ro-Ro t                                   0.122009         1.000000
# TEUS Contenedores                                 0.793998         0.239676
# Total_pasajeros                                  -0.226522         0.420999
# Anios                                            -0.116883        -0.049836
# Mes                                              -0.230613         0.031446
# Total_buques                                      0.216134         0.960099
# Total_automoviles                                -0.270107         0.300120
# Total_toneladas                                   0.936911         0.393935
#
#                                   TEUS Contenedores  Total_pasajeros  \
# Graneles Líquidos t                       -0.057692        -0.380877
# Graneles Sólidos t                        -0.023131        -0.200475
# Mercancía General t                        0.909804         0.144735
# Mercancia General Contenedores t           0.944355         0.064809
# Mercancías En Tránsito t                   0.793998        -0.226522
# Tráfico Ro-Ro t                            0.239676         0.420999
# TEUS Contenedores                          1.000000         0.122279
# Total_pasajeros                            0.122279         1.000000
# Anios                                      0.142249        -0.013085
# Mes                                       -0.210440         0.479413
# Total_buques                               0.332172         0.479705
# Total_automoviles                          0.071504         0.864541
# Total_toneladas                            0.834414        -0.056763
#
#                                      Anios       Mes  Total_buques  \
# Graneles Líquidos t              -0.507212  0.070257     -0.010539
# Graneles Sólidos t               -0.046000  0.002151      0.213638
# Mercancía General t              -0.068289 -0.182399      0.581195
# Mercancia General Contenedores t -0.062615 -0.206955      0.386285
# Mercancías En Tránsito t         -0.116883 -0.230613      0.216134
# Tráfico Ro-Ro t                  -0.049836  0.031446      0.960099
# TEUS Contenedores                 0.142249 -0.210440      0.332172
# Total_pasajeros                  -0.013085  0.479413      0.479705
# Anios                             1.000000 -0.298696     -0.081859
# Mes                              -0.298696  1.000000     -0.031791
# Total_buques                     -0.081859 -0.031791      1.000000
# Total_automoviles                 0.087907  0.493271      0.312655
# Total_toneladas                  -0.189418 -0.175106      0.476373
#
#                                   Total_automoviles  Total_toneladas
# Graneles Líquidos t                       -0.364546         0.393363
# Graneles Sólidos t                        -0.073166         0.146296
# Mercancía General t                        0.038288         0.934589
# Mercancia General Contenedores t          -0.022301         0.924244
# Mercancías En Tránsito t                  -0.270107         0.936911
# Tráfico Ro-Ro t                            0.300120         0.393935
# TEUS Contenedores                          0.071504         0.834414
# Total_pasajeros                            0.864541        -0.056763
# Anios                                      0.087907        -0.189418
# Mes                                        0.493271        -0.175106
# Total_buques                               0.312655         0.476373
# Total_automoviles                          1.000000        -0.129260
# Total_toneladas                           -0.129260         1.000000

# %% [markdown]
# # Matriz de Correlaciones

# %%
# Heatmap Matriz de Correlaciones 
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20, 20))

sns.heatmap(
    data = corr_matriz_barcelona,
    annot= True,
    cbar= True,
    annot_kws={"size":8},
    vmin= -1,
    vmax=1,
    center=0,
    cmap = sns.diverging_palette(20, 220, n=200),
    square= True,
    ax= ax,
    linewidths=.5,
    cbar_kws={"shrink":.5}
)

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation = 45,
    horizontalalignment = 'right',
)

ax.tick_params(labelsize=10)
plt.title('Matriz de Correlación Barcelona')
# Out:
# Text(0.5, 1.0, 'Matriz de Correlación Barcelona')

# %% [markdown]
# Elección de variables con una correlación mayor del 75%
# - Mercancía General t
# - Mercancia General Contenedores t
# - Mercancías En Tránsito t
# - TEUS Contenedores
#
#
# - Total_toneladas

# %%
# Selección
from sklearn.model_selection import train_test_split

df = df_barcelona[['Mercancía General t', 'Mercancia General Contenedores t', 'Mercancías En Tránsito t', 'TEUS Contenedores', 'Total_toneladas']]

train, test = train_test_split(df, test_size=0.30, shuffle=False)

# %%
# Reseteamos el index con el fin de evitar problemas en la validación cruzada

train.reset_index(drop=True, inplace= True)
train.head()
# Out:
#    Mercancía General t  Mercancia General Contenedores t  \
# 0              3811267                           3015822
# 1              3658040                           2740901
# 2              4474862                           3461354
# 3              4300236                           3380549
# 4              4678231                           3625521
#
#    Mercancías En Tránsito t  TEUS Contenedores  Total_toneladas
# 0                   2122201          293935.75         11518969
# 1                   1901341          264193.50         11001335
# 2                   2828676          319486.00         13816156
# 3                   2243082          301119.50         12314599
# 4                   2417518          333401.50         13594797

# %% [markdown]
# # 1. Parametrización
#
# Elección: KNeighbors, k y Pesos se van a parametrizar para ello se ejecutará [validación cruzada] t como medida de éxito [MAE]

# %%
from sklearn import neighbors
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error
import numpy as np

cv = KFold(n_splits =5, shuffle = False) #
# se podría utilizar https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html 


for i, weights in enumerate(['uniform', 'distance']):
   total_scores = []
   for n_neighbors in range(1,13):
       fold_accuracy = []
       knn = neighbors.KNeighborsRegressor(n_neighbors, weights=weights)

       # verificar cada uno de los modelos con validación cruzada.
       for train_fold, test_fold in cv.split(train):
          # División train test aleatoria
          f_train = train.loc[train_fold]
          f_test = train.loc[test_fold]
          # entrenamiento y ejecución del modelo
          knn.fit( X = f_train.drop(['Total_toneladas'], axis=1), 
                               y = f_train['Total_toneladas'])
          y_pred = knn.predict(X = f_test.drop(['Total_toneladas'], axis = 1))
          # evaluación del modelo
          mae = mean_absolute_error(f_test['Total_toneladas'], y_pred)
          fold_accuracy.append(mae)
       total_scores.append(sum(fold_accuracy)/len(fold_accuracy))
   
   plt.plot(range(1,len(total_scores)+1), total_scores, 
             marker='o', label=weights)
   print ('Min Value ' +  weights + " : " +  str(min(total_scores)) +" (" + str(np.argmin(total_scores) + 1) + ")")
   plt.ylabel('MAE')      
    

plt.legend()
plt.show()
# Out:
# Min Value uniform : 342626.7833333333 (2)
# Min Value distance : 326621.2754384816 (4)

# %% [markdown]
# # 2. Construcción y ejecución del modelo

# %%
# Constructor 
n_neighbors = 2
weights = 'uniform'
knn = neighbors.KNeighborsRegressor(n_neighbors=n_neighbors, weights=weights)

# fit and predict
knn.fit(X= train.drop(['Total_toneladas'], axis=1), y= train['Total_toneladas'])
y_pred = knn.predict(X=test.drop(['Total_toneladas'], axis=1))
mae = mean_absolute_error(test['Total_toneladas'], y_pred)

print('MAE:', mae)
# Out:
# MAE: 336661.05555555556

# %%
# Constructor 
n_neighbors = 3
weights = 'uniform'
knn = neighbors.KNeighborsRegressor(n_neighbors=n_neighbors, weights=weights)

# fit and predict
knn.fit(X= train.drop(['Total_toneladas'], axis=1), y= train['Total_toneladas'])
y_pred = knn.predict(X=test.drop(['Total_toneladas'], axis=1))
mae = mean_absolute_error(test['Total_toneladas'], y_pred)

print('MAE:', mae)
# Out:
# MAE: 302043.1111111111

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
mse_knn = mean_squared_error(test['Total_toneladas'], y_pred)
rmse_knn = np.sqrt(mse_knn)
r2_knn= r2_score(test['Total_toneladas'], y_pred)

# %%
print(f"KNN - MAE: {mae}, MSE: {mse_knn}, RMSE: {rmse_knn}, R2: {r2_knn}")
# Out:
# KNN - MAE: 302043.1111111111, MSE: 140919815734.8642, RMSE: 375392.88183830044, R2: 0.8719048723756189

# %%
# Constructor 
n_neighbors = 4
weights = 'uniform'
knn = neighbors.KNeighborsRegressor(n_neighbors=n_neighbors, weights=weights)

# fit and predict
knn.fit(X= train.drop(['Total_toneladas'], axis=1), y= train['Total_toneladas'])
y_pred = knn.predict(X=test.drop(['Total_toneladas'], axis=1))
mae = mean_absolute_error(test['Total_toneladas'], y_pred)

print('MAE:', mae)
# Out:
# MAE: 306803.80555555556

# %%
# Redondear el resultado
res = np.rint(y_pred)
res = res.astype(int)
output = pd.DataFrame({'date':test.index, 'result':res})

output.to_csv('result.csv')

# %%
res = res.tolist()

# %%
res
# Out:
# [10656202,
#  10656202,
#  11034662,
#  11390470,
#  10684101,
#  11390470,
#  11805983,
#  13096052,
#  12669319]

# %%
test['Total_toneladas'].tolist()
# Out:
# [10005943,
#  10108634,
#  10938198,
#  11302964,
#  10386884,
#  10776039,
#  11688430,
#  13279089,
#  12544966]

# %%
from sklearn.metrics import mean_absolute_error

xx = np.arange(test['Total_toneladas'].shape[0])
plt.plot(xx, test['Total_toneladas'], c='r', label = 'data')
plt.plot(xx, y_pred, c='g', label= 'predicción')
plt.axis('tight')
plt.legend()
plt.title('KNeighborsRegressor (k = %i, weights= "%s")' % (n_neighbors, weights))

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Predecir los siguientes 6 meses


# Obtiene los últimos 6 meses de datos de entrenamiento
train_last_6_months = train.tail(12)

# Ajusta el modelo KNN utilizando los últimos 6 meses de datos de entrenamiento
knn.fit(X=train_last_6_months.drop(['Total_toneladas'], axis=1), y=train_last_6_months['Total_toneladas'])

# Crea un DataFrame vacío para almacenar las predicciones
future_predictions = pd.DataFrame(columns=['Total_toneladas'])

# Bucle para predecir los siguientes 6 meses
for i in range(6):
  # Obtiene las últimas 6 filas de datos (incluidas las predicciones)
  last_6_months = pd.concat([train_last_6_months, future_predictions])[-12:]

  # Realiza la predicción para el siguiente mes
  next_month_prediction = knn.predict(X=last_6_months.drop(['Total_toneladas'], axis=1).fillna(method='ffill'))

  # Agrega la predicción al DataFrame, convirtiendo la predicción a un DataFrame antes de concatenar
  future_predictions = pd.concat([future_predictions, pd.DataFrame({'Total_toneladas': [next_month_prediction[0]]})], ignore_index=True)

# Crea un rango de fechas para los siguientes 6 meses
future_dates = pd.date_range(start=test.index[-1] + pd.DateOffset(months=1), periods=6, freq='MS')

# Crea un DataFrame con las fechas y las predicciones
future_df = pd.DataFrame({'date': future_dates, 'result': future_predictions['Total_toneladas']})

# Concatena los datos de prueba y las predicciones futuras
combined_df = pd.concat([test, future_df])

# Gráfica de las predicciones
fig, ax = plt.subplots(figsize=(30, 10))
# Assuming 'future_data' contains data for the next 6 months
future_dates = pd.to_datetime(['2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01'])

# Assuming 'future_predictions' contains the predictions for those months
#plt.plot(future_dates, future_predictions, c='g', label='Predicción')
plt.plot(combined_df['date'], combined_df['result'], c='b', label='Predicción')

plt.plot(test.index, test['Total_toneladas'], c='r', label='Real')
plt.xlabel('Fecha')
plt.ylabel('Total toneladas')
plt.title('Predicción Barcelona')
plt.legend()
plt.show()
# Out:
# C:\Users\Encarni\AppData\Local\Temp\ipykernel_23256\4171739750.py:21: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   next_month_prediction = knn.predict(X=last_6_months.drop(['Total_toneladas'], axis=1).fillna(method='ffill'))
# C:\Users\Encarni\AppData\Local\Temp\ipykernel_23256\4171739750.py:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   future_predictions = pd.concat([future_predictions, pd.DataFrame({'Total_toneladas': [next_month_prediction[0]]})], ignore_index=True)
# C:\Users\Encarni\AppData\Local\Temp\ipykernel_23256\4171739750.py:21: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   next_month_prediction = knn.predict(X=last_6_months.drop(['Total_toneladas'], axis=1).fillna(method='ffill'))
# C:\Users\Encarni\AppData\Local\Temp\ipykernel_23256\4171739750.py:21: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   next_month_prediction = knn.predict(X=last_6_months.drop(['Total_toneladas'], axis=1).fillna(method='ffill'))
# C:\Users\Encarni\AppData\Local\Temp\ipykernel_23256\4171739750.py:21: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   next_month_prediction = knn.predict(X=last_6_months.drop(['Total_toneladas'], axis=1).fillna(method='ffill'))
# C:\Users\Encarni\AppData\Local\Temp\ipykernel_23256\4171739750.py:21: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   next_month_prediction = knn.predict(X=last_6_months.drop(['Total_toneladas'], axis=1).fillna(method='ffill'))
# C:\Users\Encarni\AppData\Local\Temp\ipykernel_23256\4171739750.py:21: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   next_month_prediction = knn.predict(X=last_6_months.drop(['Total_toneladas'], axis=1).fillna(method='ffill'))

# %%
combined_df
# Out:
#                      Mercancía General t  Mercancia General Contenedores t  \
# 2023-08-01 00:00:00            3585895.0                         2704096.0
# 2023-09-01 00:00:00            3596357.0                         2677231.0
# 2023-10-01 00:00:00            3793951.0                         2884415.0
# 2023-11-01 00:00:00            3835106.0                         2910637.0
# 2023-12-01 00:00:00            3607547.0                         2827043.0
# 2024-01-01 00:00:00            3843295.0                         3011767.0
# 2024-02-01 00:00:00            4046216.0                         3148202.0
# 2024-03-01 00:00:00            4563660.0                         3550731.0
# 2024-04-01 00:00:00            4453149.0                         3429166.0
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# 5                                    NaN                               NaN
#
#                      Mercancías En Tránsito t  TEUS Contenedores  \
# 2023-08-01 00:00:00                 1608146.0          285429.25
# 2023-09-01 00:00:00                 1584709.0          267061.25
# 2023-10-01 00:00:00                 1825130.0          272712.50
# 2023-11-01 00:00:00                 1922033.0          281291.25
# 2023-12-01 00:00:00                 1783553.0          279753.50
# 2024-01-01 00:00:00                 1989352.0          295527.75
# 2024-02-01 00:00:00                 2177589.0          308120.50
# 2024-03-01 00:00:00                 2561161.0          348007.00
# 2024-04-01 00:00:00                 2290086.0          338986.25
# 0                                         NaN                NaN
# 1                                         NaN                NaN
# 2                                         NaN                NaN
# 3                                         NaN                NaN
# 4                                         NaN                NaN
# 5                                         NaN                NaN
#
#                      Total_toneladas       date        result
# 2023-08-01 00:00:00       10005943.0        NaT           NaN
# 2023-09-01 00:00:00       10108634.0        NaT           NaN
# 2023-10-01 00:00:00       10938198.0        NaT           NaN
# 2023-11-01 00:00:00       11302964.0        NaT           NaN
# 2023-12-01 00:00:00       10386884.0        NaT           NaN
# 2024-01-01 00:00:00       10776039.0        NaT           NaN
# 2024-02-01 00:00:00       11688430.0        NaT           NaN
# 2024-03-01 00:00:00       13279089.0        NaT           NaN
# 2024-04-01 00:00:00       12544966.0        NaT           NaN
# 0                                NaN 2024-05-01  1.186521e+07
# 1                                NaN 2024-06-01  1.101624e+07
# 2                                NaN 2024-07-01  1.101624e+07
# 3                                NaN 2024-08-01  1.050619e+07
# 4                                NaN 2024-09-01  1.099680e+07
# 5                                NaN 2024-10-01  1.065620e+07
